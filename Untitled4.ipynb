# %%
# %matplotlib notebook
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
df = pd.read_csv("new_train.csv", header=0)


df=df.dropna()

# %%
a=['Homepage', 'Homepage _Duration', 'Aboutus', 'Aboutus_Duration',
       'Contactus', 'Contactus_Duration', 'BounceRates', 'ExitRates',
       'PageValues', 'SpecialDay', 'Month', 'OperatingSystems', 'Browser',
       'Province', 'TrafficType', 'VisitorType', 'Weekend', 'Revenue']

# %%
from itertools import combinations
from sklearn import preprocessing
perm = combinations(a, 10)
features=list(perm)
feture_list=[]
for i in range(len(features)):
    feture=df[list(features[i])]
    feture=preprocessing.scale(feture)
    feture_list.append(feture)
y = df['Revenue']

# %%
features
# Out:
# [('Homepage',
#   'Homepage _Duration',
#   'Aboutus',
#   'Aboutus_Duration',
#   'Contactus',
#   'Contactus_Duration',
#   'BounceRates',
#   'ExitRates',
#   'PageValues',
#   'SpecialDay',
#   'Month',
#   'OperatingSystems',
#   'Browser',
#   'Province',
#   'TrafficType',
#   'VisitorType'),
#  ('Homepage',
#   'Homepage _Duration',
#   'Aboutus',
#   'Aboutus_Duration',
#   'Contactus',
#   'Contactus_Duration',
#   'BounceRates',
#   'ExitRates',
#   'PageValues',
#   'SpecialDay',
#   'Month',
#   'OperatingSystems',
#   'Browser',
#   'Province',
#   'TrafficType',
#   'Weekend'),
#  ('Homepage',
#   'Homepage _Duration',
#   'Aboutus',
#   'Aboutus_Duration',
#   'Contactus',
#   'Contactus_Duration',
#   'BounceRates',
#   'ExitRates',
#   'PageValues',
#   'SpecialDay',
#   'Month',
#   'OperatingSystems',
#   'Browser',
#   'Province',
#   'TrafficType',
#   'Revenue'),
#  ('Homepage',
#   'Homepage _Duration',
#   'Aboutus',
#   'Aboutus_Duration',
#   'Contactus',
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
for k in range(len(feture_list)):
    x_train, x_validation, y_train, y_validation = train_test_split(feture_list[k], y, test_size = 0.2,random_state=42)
    
    clf=RandomForestClassifier(n_estimators=100,max_features='auto',random_state=0,
                              max_depth=10)
    clf.fit(x_train,y_train)

    y_pred=clf.predict(x_validation)
    from sklearn import metrics

    print("Accuracy:",metrics.accuracy_score(y_validation, y_pred))
# Out:
# Accuracy: 0.9054441260744985
# Accuracy: 0.9054441260744985
# Accuracy: 1.0
# Accuracy: 0.9068767908309455
# Accuracy: 1.0
# Accuracy: 1.0
# Accuracy: 0.9049665711556829
# Accuracy: 1.0
# Accuracy: 1.0
# Accuracy: 1.0
# Accuracy: 0.9054441260744985
# Accuracy: 1.0
# Accuracy: 1.0
# Accuracy: 1.0
# Accuracy: 1.0
# Accuracy: 0.9040114613180515
# Accuracy: 1.0
# Accuracy: 1.0
# Accuracy: 1.0
# Accuracy: 1.0
# Accuracy: 1.0
# Accuracy: 0.9016236867239733
# Accuracy: 1.0
# Accuracy: 1.0
# Accuracy: 1.0
# Accuracy: 1.0
# Accuracy: 1.0
# Accuracy: 1.0
# Accuracy: 0.9030563514804203
# Accuracy: 1.0
# Accuracy: 1.0
# Accuracy: 1.0
# Accuracy: 1.0
# Accuracy: 1.0
# Accuracy: 1.0
# Accuracy: 1.0
# Accuracy: 0.8457497612225406
# Accuracy: 1.0
# Accuracy: 1.0
# Accuracy: 1.0
# Accuracy: 1.0
# Accuracy: 1.0
# Accuracy: 1.0
# Accuracy: 1.0
# Accuracy: 1.0
# Accuracy: 0.9040114613180515
# Accuracy: 1.0
# Accuracy: 1.0
# Accuracy: 1.0
# Accuracy: 1.0
# Accuracy: 1.0
# Accuracy: 1.0
# Accuracy: 1.0
# ...
